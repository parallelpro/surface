# %%
# %run setup.py

# %%
ic_cols = ['a', 'b', 'c', 'd', "a'", "b'", "c'", "d'" ]
ic_ecols = ['e_a', 'e_b', 'e_c', 'e_d', "e_a'", "e_b'", "e_c'", "e_d'" ]

c_cols = ['a', 'b', 'c', 'd', ]
c_ecols = ['e_a', 'e_b', 'e_c', 'e_d', ]


cols = ['Sample', 'Model' ]

data = pd.DataFrame([
    {'Atmosphere': 'Eddington',
     'Sample': 'All', 
     'Model': 'Cubic', 
     **{k:v for k,v in zip(c_cols,[-4.1485624, 0.9450712, -5.479969 , -1.0995963])},
     **{k:v for k,v in zip(c_ecols,[0.13009433, 0.01215709, 0.23190716, 0.02584277])},
    },
    {'Atmosphere': 'Eddington',
     'Sample': 'Pre-RGB', 
     'Model': 'Cubic', 
     **{k:v for k,v in zip(c_cols,[-4.186023 , 0.7813644 , -5.7118735 , -0.07299965])},
     **{k:v for k,v in zip(c_ecols,[0.3921687 , 0.06778456, 0.5822848 , 0.13034512])},
    },
    {'Atmosphere': 'Eddington',
     'Sample': 'RGB', 
     'Model': 'Cubic', 
     **{k:v for k,v in zip(c_cols,[-4.181521 , 0.95523196, -5.6379514 , -1.1099834 ])},
     **{k:v for k,v in zip(c_ecols,[0.13015431, 0.01164923, 0.22260946, 0.02455296])},
    },
    
    {'Atmosphere': 'Eddington',
     'Sample': 'All', 
     'Model': 'Inverse-cubic', 
     **{k:v for k,v in zip(ic_cols,[-3.7443726, 1.0866573, -8.742777 , -1.3795667, -4.9891973, 1.0541984, -8.15369 , -1.3154854])},
     **{k:v for k,v in zip(ic_ecols,[0.13330452, 0.01283954, 0.22996646, 0.02094826, 0.13725656, 0.00977644, 0.18469958, 0.01802539])}, 
    },
    {'Atmosphere': 'Eddington',
     'Sample': 'Pre-RGB', 
     'Model': 'Inverse-cubic', 
     **{k:v for k,v in zip(ic_cols,[-3.715097 , 0.6096728 , -1.6813153 , -0.08168457, -5.550722 , 0.6479634 , -1.5653569 , -0.64631474])},
     **{k:v for k,v in zip(ic_ecols,[0.40209517, 0.0793009 , 0.82480085, 0.1394154 , 0.42107266, 0.05699116, 0.6225904 , 0.11118653])},
    },
    {'Atmosphere': 'Eddington',
     'Sample': 'RGB', 
     'Model': 'Inverse-cubic', 
     **{k:v for k,v in zip(ic_cols,[-3.8369734, 1.0976515, -8.83042 , -1.3841832, -5.0435867, 1.0658274, -8.325036 , -1.3250351])},
     **{k:v for k,v in zip(ic_ecols,[0.16418463, 0.01225858, 0.24061048, 0.02119218, 0.16585062, 0.00967092, 0.1921673 , 0.01829769])},
    },
    
    {'Atmosphere': 'Hopf',
     'Sample': 'All', 
     'Model': 'Cubic', 
     **{k:v for k,v in zip(c_cols,[-3.064004 , 0.96079797, -7.144836 , -0.8798956 ])},
     **{k:v for k,v in zip(c_ecols,[0.09832186, 0.00993515, 0.20343256, 0.02072822])},
    },
    {'Atmosphere': 'Hopf',
     'Sample': 'Pre-RGB', 
     'Model': 'Cubic', 
     **{k:v for k,v in zip(c_cols,[-4.245544 , 0.5040414 , -0.9813989 , -0.48889992])},
     **{k:v for k,v in zip(c_ecols,[0.27737832, 0.0578146 , 0.48618144, 0.08239575])},
    },
    {'Atmosphere': 'Hopf',
     'Sample': 'RGB', 
     'Model': 'Cubic', 
     **{k:v for k,v in zip(c_cols,[-2.9030428 , 0.97364545, -7.6786346 , -0.91186076])},
     **{k:v for k,v in zip(c_ecols,[0.09598602, 0.0110919 , 0.22213084, 0.02060322])},
    },
    
    
    {'Atmosphere': 'Hopf',
     'Sample': 'All', 
     'Model': 'Inverse-cubic', 
     **{k:v for k,v in zip(ic_cols,[-4.730426 , 0.44938794, 2.2742143 , 0.6649345 , -6.012242 , 0.50756603, 1.5871831 , 0.31629565])},
     **{k:v for k,v in zip(ic_ecols,[0.40055206, 0.05865041, 0.43102598, 0.11203981, 0.3800276 , 0.04579416, 0.35854703, 0.09796833])}, 
    },
    {'Atmosphere': 'Hopf',
     'Sample': 'Pre-RGB', 
     'Model': 'Inverse-cubic', 
     **{k:v for k,v in zip(ic_cols,[-4.730426 , 0.44938794, 2.2742143 , 0.6649345 , -6.012242 , 0.50756603, 1.5871831 , 0.31629565])},
     **{k:v for k,v in zip(ic_ecols,[0.40055206, 0.05865041, 0.43102598, 0.11203981, 0.3800276 , 0.04579416, 0.35854703, 0.09796833])},
    },
    {'Atmosphere': 'Hopf',
     'Sample': 'RGB', 
     'Model': 'Inverse-cubic', 
     **{k:v for k,v in zip(ic_cols,[ -1.4532081 , 0.87606186, -10.1614065 , -0.31404772, -2.310592 , 0.89685166, -9.446557 , -0.502116 ])},
     **{k:v for k,v in zip(ic_ecols,[0.03458241, 0.01137423, 0.19651969, 0.02047572, 0.05806956, 0.00949883, 0.17697607, 0.01874554])},
    },
])

data
# Out:
#    Atmosphere   Sample          Model         a         b          c  \
# 0   Eddington      All          Cubic -4.148562  0.945071  -5.479969
# 1   Eddington  Pre-RGB          Cubic -4.186023  0.781364  -5.711874
# 2   Eddington      RGB          Cubic -4.181521  0.955232  -5.637951
# 3   Eddington      All  Inverse-cubic -3.744373  1.086657  -8.742777
# 4   Eddington  Pre-RGB  Inverse-cubic -3.715097  0.609673  -1.681315
# 5   Eddington      RGB  Inverse-cubic -3.836973  1.097652  -8.830420
# 6        Hopf      All          Cubic -3.064004  0.960798  -7.144836
# 7        Hopf  Pre-RGB          Cubic -4.245544  0.504041  -0.981399
# 8        Hopf      RGB          Cubic -2.903043  0.973645  -7.678635
# 9        Hopf      All  Inverse-cubic -4.730426  0.449388   2.274214
# 10       Hopf  Pre-RGB  Inverse-cubic -4.730426  0.449388   2.274214
# 11       Hopf      RGB  Inverse-cubic -1.453208  0.876062 -10.161407
#
# ...

# %%
def my_write_latex_table(listofcol, listofcolerr, listofcolname, listofcolformat, listofcolerrformat, filename, expandcolumns=True, scaption='', slabel='', snote='', sfootnote='',align=None):
    # version 2 - modified in 20/Dec/2018 - added footnote

    # test if input lists are of equal length
    a, b, c, d, e = [len(obj) for obj in [listofcol, listofcolerr, listofcolname, listofcolformat, listofcolerrformat]]
    assert a == b == c == d == e

    # configure footnote
    if sfootnote == '':
        footnote = ''
    else:
        footnote = '\n \\begin{tablenotes}  \n \\item \\emph{Note}: ' + sfootnote + '\n \\end{tablenotes}'

    # create a pandas table

    listofdata = [[listofcolformat[tcol].format(listofcol[tcol][trow]) + listofcolerrformat[tcol].format(listofcolerr[tcol][trow])  for trow in range(len(listofcol[0]))] 
        for tcol in range(len(listofcol))]

    table = pd.DataFrame(np.array(listofdata).T, columns = listofcolname)

    f = open(filename,'w')

    stable = 'table*' if expandcolumns else 'table'
    f.write('\\begin{'+stable+'} \n')
#     f.write('\tiny \n')
    f.write('\caption{'+scaption+' \n')
    f.write('\label{'+slabel+'} \\\\ \n')
    f.write(snote+'} \n')


    ncol = table.shape[1]
    if align is None: align = 'l'+'c'*ncol
    s = table.to_latex(index=False, float_format='%.2f', escape=False, column_format=''+align) #@{\extracolsep{\\fill}}
    width = 'textwidth' if expandcolumns else 'columnwidth'
    s = s.replace('\\begin{tabular}', '\\begin{tabular*}{1.01\\'+width+'}')
    s = s.replace('\\end{tabular}', '\\end{tabular*}'+footnote)

    f.write(s)

    f.write('\\end{'+stable+'} \n')
    f.close()

# %%
cols = ['a', 'b', 'c', 'd', 
        "a'", "b'", "c'", "d'" ]

f = '${:0.2f} \\pm {:0.2f}$'

listofcol1 = [ data['Atmosphere'].to_numpy(),
               data['Model'].to_numpy(),
               data['Sample'].to_numpy(),
              [f.format(data.loc[i,'a'], data.loc[i,'e_a']) for i in range(12)], 
              [f.format(data.loc[i,'b'], data.loc[i,'e_b']) for i in range(12)], 
              [f.format(data.loc[i,'c'], data.loc[i,'e_c']) for i in range(12)], 
              [f.format(data.loc[i,'d'], data.loc[i,'e_d']) for i in range(12)], 
              [*(['---']*3), *[f.format(data.loc[i,"a'"], data.loc[i,"e_a'"]) for i in range(3,6)]] +\
               [*(['---']*3), *[f.format(data.loc[i,"a'"], data.loc[i,"e_a'"]) for i in range(9,12)]], 
              [*(['---']*3), *[f.format(data.loc[i,"b'"], data.loc[i,"e_b'"]) for i in range(3,6)]] +\
               [*(['---']*3), *[f.format(data.loc[i,"a'"], data.loc[i,"e_a'"]) for i in range(9,12)]], 
              [*(['---']*3), *[f.format(data.loc[i,"c'"], data.loc[i,"e_c'"]) for i in range(3,6)]] +\
               [*(['---']*3), *[f.format(data.loc[i,"a'"], data.loc[i,"e_a'"]) for i in range(9,12)]],  
              [*(['---']*3), *[f.format(data.loc[i,"d'"], data.loc[i,"e_d'"]) for i in range(3,6)]] +\
               [*(['---']*3), *[f.format(data.loc[i,"a'"], data.loc[i,"e_a'"]) for i in range(9,12)]] ]

listofcolerr1 = listofcol1
listofcolname1 = ['Atmosphere', 'Model', 'Sample', "$a$", "$b$", "$c$", "$d$", "$a'$", "$b'$", "$c'$", "$d'$"]
listofcolformat = ['{:s}']*3 +  ['{:s}']*8
listofcolerrformat = ['']*11

blistofcol = listofcol1
blistofcolerr = listofcolerr1
blistofcolname = listofcolname1
blistofcolformat = listofcolformat
blistofcolerrformat = listofcolerrformat

caption = 'Best-fitting parameters in the surface correction prescriptions'
filename = 'Tab.2_surf_corr.txt'
label = 'tab:surf-corr'
align = r'@{\extracolsep{\fill}}lllrrrrrrrrrr'
my_write_latex_table(blistofcol, blistofcolerr, blistofcolname, blistofcolformat, blistofcolerrformat, filename, 
	expandcolumns=True, scaption=caption, slabel=label, align=align)
# os.system(to_overleaf(filename, 'tables'))
